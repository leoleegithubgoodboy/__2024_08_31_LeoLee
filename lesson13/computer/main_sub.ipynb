# %%
import os
#os.path.abspath(__name__)
rood_dir = os.getcwd()
print(rood_dir)
data_dir = os.path.join(rood_dir,'data')
print(data_dir)
if os.path.isdir(data_dir):
    print("有目錄")
else:
    print("沒目錄")
# Out:
# c:\Users\leole\Documents\GitHub\__2024_08_31_LeoLee\lesson13\computer
# c:\Users\leole\Documents\GitHub\__2024_08_31_LeoLee\lesson13\computer\data
# 有目錄
